# %% [markdown]
# <a href="https://colab.research.google.com/github/GalaAldebara/PCVK_IqbalMakmur/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
        # baca dan tampilkan image
        # loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-dca4e82e6184> in <cell line: 7>()
#       6         # loop pada tiap url image, beberapa image dapat disimpan pada list
#       7 for url in urls:
# ----> 8   image = io.imread(url)
#       9   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#      10   image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      57             plugin = 'tifffile'
#      58
# ---> 59     with file_or_url_context(fname) as fname:
#      60         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      61
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     133         del self.args, self.kwds, self.func
# ...

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Pertanyaan
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# 2.   Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
#   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#   Apa kegunaankode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
# 4. Perhatikan potongan kode program berikut, Apakah kegunaan kode (255,255,255) ? Jelaskan!
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!

# %% [markdown]
# Jawaban
#
# 1.   Integrasi dengan Github sehingga memudahkan pekerjaan, dapat berkolaborasi sehingga dapat berbagi notebook dan bekerja bersama-sama secara real-time, Google colab menyediakan akses gratis ke GPU dan TPU yang dapat membantu untuk komputasi yang berat seperti pemrosesan gambar.
# 2.   Kegunaan Library
#       * NumpPy digunakan untuk komputasi numerik, terutama manipulasi array dan operasi matematis.
#       * Pandas digunakan untuk manipulasi dan analisis data, terutama struktur data berbasis tabel seperti DataFrame.
#       * OpenCV digunakan untuk pemrosesan gambar dan video
#       * Google Colab Patches digunakan untuk menampilkan gambar menggunakan OpenCV dalam Google Colab.
#       * Scikit-Image digunakan untuk membaca gambar dari URL dan melakukan transformasi gambar.
#       * PIL digunakan untuk manipulasi gambar
#       * Matpotlib digunakan untuk visualisasi data, seperti grafik.
#
#     Terdapat 3 library yang tidak digunakan pada kode program diatas, yaitu Pandas, PIL, dan Matplotlib
#
# 3. Digunakan untuk mengubah ukuran skala gambar menjadi 0.5 dengan lebar 0.5 dan tinggi 0.5. Jika gambar tidak di resize maka gambar akan terlalu besar dan memakan banyak memori untuk diproses
#
# 4. Kode (255,255,255) digunakan untuk mendefinisikan putih dalam format RGB.
#
# 5. Pixel adalah unit dasar dari sebuah gambar digital, yang merepresentasikan sebuah titik tunggal dalam gambar, sedangkan resolusi gambar adalah jumlah pixel yang terdapat dalam sebuah gambar, biasanya dinyatakan dalam bentuk dimensi horizontal x vertikal jadi semakin tinggi resolusi makan akan memiliki lebih banyak pixel, sebaliknya jika resolusi semakin rendah akan memiliki lebih sedikit pixel.

# %% [markdown]
# TUGAS

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io

# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",]
for url in urls:
    image = io.imread(url)                          # Baca gambar
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # Resize gambar ke ukuran setengah
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # Ubah warna ke RGB

    image_before = image.copy()

    start_point_vertical = (image.shape[1] // 2, 0)
    end_point_vertical = (image.shape[1] // 2, image.shape[0])
    color = (255, 255, 255)
    thickness = 1
    image_with_line = cv.line(image.copy(), start_point_vertical, end_point_vertical, color, thickness)

    final_image = cv.hconcat([image_before, image_with_line])
    cv2_imshow(final_image)
    print('\n')

# Loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)                          # Baca gambar
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # Resize gambar ke ukuran setengah
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # Ubah warna ke RGB

    image_before = image.copy()

    start_point_diag1 = (0, 0)
    end_point_diag1 = (image.shape[1], image.shape[0])
    color = (255, 255, 255)
    thickness = 1
    image_with_line = cv.line(image.copy(), start_point_diag1, end_point_diag1, color, thickness)

    start_point_diag2 = (0, image.shape[0])
    end_point_diag2 = (image.shape[1], 0)
    image_with_line = cv.line(image_with_line, start_point_diag2, end_point_diag2, color, thickness)

    final_image = cv.hconcat([image_before, image_with_line])
    cv2_imshow(final_image)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x276>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io

# Membuat list untuk menyimpan URL dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",]

for url in urls:
    image = io.imread(url)                          # Baca gambar
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # Resize gambar ke ukuran setengah
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # Ubah warna ke RGB

    image_before = image.copy()

    margin = 100
    start_point_horizontal = (margin, image.shape[0] // 2)
    end_point_horizontal = (image.shape[1] - margin, image.shape[0] // 2)

    color = (255, 255, 255)  # Warna putih
    thickness = 1
    image_with_line = cv.line(image.copy(), start_point_horizontal, end_point_horizontal, color, thickness)

    final_image = cv.hconcat([image_before, image_with_line])
    cv2_imshow(final_image)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io

# Membuat list untuk menyimpan URL dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",]

for url in urls:
    image = io.imread(url)                          # Baca gambar
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # Resize gambar ke ukuran setengah
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # Ubah warna ke RGB

    image_before = image.copy()

    rect_width = 100  # Lebar kotak
    rect_height = 100  # Tinggi kotak

    start_point_rect = (image.shape[1] // 2 - rect_width // 2, image.shape[0] // 2 - rect_height // 2)
    end_point_rect = (start_point_rect[0] + rect_width, start_point_rect[1] + rect_height)

    color = (255, 255, 255)  # Warna putih
    thickness = -1
    image_with_rectangle = cv.rectangle(image.copy(), start_point_rect, end_point_rect, color, thickness)

    final_image = cv.hconcat([image_before, image_with_rectangle])
    cv2_imshow(final_image)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# Membaca gambar
image = cv.imread('/content/KTP.jpeg')

x1, y1 = 190, 321
width, height = 350, 25

cv.rectangle(image, (x1, y1), (x1 + width, y1 + height), (255, 255, 0), -2)

x1, y1 = 190, 348
width, height = 90, 20

cv.rectangle(image, (x1, y1), (x1 + width, y1 + height), (0, 128, 0), -1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x488>
